# %% [markdown]
# <a href="https://colab.research.google.com/github/wilmar8/curso-introduccion-programacion-cientifica/blob/main/ejercicios/Clase1ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicios

# %%
print("Hola mundo")
# Out:
# Hola mundo
